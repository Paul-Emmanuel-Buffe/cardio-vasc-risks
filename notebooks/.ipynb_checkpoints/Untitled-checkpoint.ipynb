# %% [markdown]
# # Boring stuff learning basic Python by practice

# %%
len('Salut Paul-Emmanuel')
# Out:
# 19

# %%
liste = [ 10, 52, 69, 89]
len(liste)
# Out:
# 4

# %%
print('I am ', 29, 'years old')
# Out:
# I am  29 years old

# %%
'I am' + ' 56 ' + 'years old'
# Out:
# 'I am 56 years old'

# %%
int('56')
# Out:
# 56

# %%
int('kl')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 int('kl')
#
# ValueError: invalid literal for int() with base 10: 'kl'

# %%
str(56)
# Out:
# '56'

# %%
spam = input('Merci de rentrer un nombre: ')
spam
int(spam)
# Out:
# Merci de rentrer un nombre:  42
# 42

# %%
print('What is your age ?: ')
my_age = input('>')
print('Ok, you will be', (int(my_age) + 1), 'in a year !')
# Out:
# What is your age ?:
# > 51
# Ok, you will be 52 in a year !

# %%
type(45)
# Out:
# int

# %%
type('Paul-Emmanuel')
# Out:
# str

# %%
type(45.2)
# Out:
# float

# %%
number= 51
type(number)
# Out:
# int

# %%
number = str(51)
type(number)
# Out:
# str

# %%
type(len(number))
# Out:
# int

# %%
round(3.14)
# Out:
# 3

# %%
round(3.14, 1)
# Out:
# 3.1

# %%
round(3.99)
# Out:
# 4

# %%
round(3.7777777, 3)
# Out:
# 3.778

# %%
abs(-69)
# Out:
# 69

# %%
abs(-9.6)
# Out:
# 9.6

# %%
'spam'* 3
# Out:
# 'spamspamspam'

# %%
bin(10)
# Out:
# '0b1010'

# %%
int(bin(10))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 int(bin(10))
#
# ValueError: invalid literal for int() with base 10: '0b1010'

# %%
format(14, 'b')
# Out:
# '1110'

# %%
int(format(14, 'b'))
# Out:
# 1110

# %%
hex(6999)
# Out:
# '0x1b57'

# %%
hex(-45)
# Out:
# '-0x2d'

# %%
format(56, '#x')
# Out:
# '0x38'

# %%
format(56,'x')
# Out:
# '38'

# %%
format(56, 'X')
# Out:
# '38'

# %% [markdown]
# ## 2. IF-ELSE AND FLOW CONTROL

# %% [markdown]
# ### Boolean Values

# %%
spam = True
spam
# Out:
# True

# %%
False = 4 + 4
# Out:
#   Cell In[45], line 1
#     False = 4 + 4
#     ^
# SyntaxError: cannot assign to False

# %%
false = 4 + 4
false
# Out:
# 8

# %%
8 == 4 + 4
# Out:
# True

# %%
8 == 0 + 9
# Out:
# False

# %%
'dog' == 'dog'
# Out:
# True

# %%
'Dog' == 'dog'
# Out:
# False

# %%
'dog' != 'cat'
# Out:
# True

# %%
8 >= 6
# Out:
# True

# %%
8 >= 9
# Out:
# False

# %%
42 == '42'
# Out:
# False

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
False and False
# Out:
# False

# %%
False or True
# Out:
# True

# %%
True or True
# Out:
# True

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %%
not not True
# Out:
# True

# %%
not not not True
# Out:
# False

# %%
(8==8) and (7>5)
# Out:
# True

# %%
(88==100) or (78<98)
# Out:
# True

# %%
(88>=56) and not (78<=25)
# Out:
# True

# %%
spam = 80 + 8
(spam == 88) and ((spam+1)==89)  and not spam * 2 == 177
# Out:
# True

# %%
username = 'Paul'
password = 'PeB'

if input("Username :") == username:
    print('Hello Paul')
    if input ("Password :") == password:
        print ('Access granted')
    else:
        print('Access denied')
else:
    print('Access denied')
# Out:
# Username : Paul
# Hello Paul
# Password : PeB
# Access granted
